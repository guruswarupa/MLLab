# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("saurabh00007/iriscsv")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1.28k/1.28k [00:00<00:00, 1.97MB/s]
# Extracting files...
# Path to dataset files: /home/guru/.cache/kagglehub/datasets/saurabh00007/iriscsv/versions/1

# %%
import pandas as pd

# %%
iris = pd.read_csv("/home/guru/.cache/kagglehub/datasets/saurabh00007/iriscsv/versions/1/Iris.csv")
iris = iris.drop(columns='Id')

# %%
print(iris)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
print(iris.shape)
# Out:
# (150, 5)

# %%
print(iris.shape[0])
# Out:
# 150

# %%
iris[iris['PetalLengthCm']==1.5]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 3             4.6           3.1            1.5           0.2  Iris-setosa
# 7             5.0           3.4            1.5           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa
# 15            5.7           4.4            1.5           0.4  Iris-setosa
# 19            5.1           3.8            1.5           0.3  Iris-setosa
# 21            5.1           3.7            1.5           0.4  Iris-setosa
# 27            5.2           3.5            1.5           0.2  Iris-setosa
# 31            5.4           3.4            1.5           0.4  Iris-setosa
# 32            5.2           4.1            1.5           0.1  Iris-setosa
# 34            4.9           3.1            1.5           0.1  Iris-setosa
# 37            4.9           3.1            1.5           0.1  Iris-setosa
# ...

# %%
iris_virginica = iris[iris['Species'] == 'Iris-virginica']
iris_setosa = iris[iris['Species'] == 'Iris-setosa']
iris_versicolor = iris[iris['Species'] == 'Iris-versicolor']
print(iris_virginica.head(5))
print(iris_setosa.head(5))
print(iris_versicolor.head(5))
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 100            6.3           3.3            6.0           2.5  Iris-virginica
# 101            5.8           2.7            5.1           1.9  Iris-virginica
# 102            7.1           3.0            5.9           2.1  Iris-virginica
# 103            6.3           2.9            5.6           1.8  Iris-virginica
# 104            6.5           3.0            5.8           2.2  Iris-virginica
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
# ...

# %%
ax = iris.plot()
ax.set_title("Iris Dataset")
ax.set_xlabel("Data Points")
ax.set_ylabel("Length/Width (mm)")
# Out:
# Text(0, 0.5, 'Length/Width (mm)')

# %%
iris["SepalLengthCm"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris["PetalLengthCm"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>
